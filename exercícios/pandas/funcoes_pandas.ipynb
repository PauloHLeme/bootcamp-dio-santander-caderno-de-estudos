# %%
# importando a biblioteca Pandas
import pandas as pd

# %%
# criando o DataFrame a partir de um arquivo CSV
df_livros = pd.read_csv('livros_stephen_king.csv')

# %%
# Exibindo o arquivo
df_livros

# %%
# Exibindo apenas as 3 primeiras linhas com a função head()
df_livros.head(3)

# %%
# Retorna informações sobre as colunas da tabela, como índice, tipo de dado, quantidade de dados...

df_livros.info()

# %%
# Exibe quantas linhas e quantas colunas o dataframe possui
print(df_livros.shape)
print(f'O documento possui {df_livros.shape[0]} linhas e {df_livros.shape[1]} colunas.')

# %%
# Exibe quais são as colunas que temos em nossa planilha
df_livros.columns
# Out:
# Index(['titulo', 'descricao', 'data_lancamento', 'link_amazon'], dtype='object')

# %%
# Podemos também definir novos valores para as colunas através deste atributo
df_livros.columns = ['titulo','sinopse','data_lancamento','link_afiliado']
print(df_livros.columns)
# Out:
# Index(['titulo', 'sinopse', 'data_lancamento', 'link_afiliado'], dtype='object')

# %%
# Descreve algumas informações bem úteis sobre os dados, especialmente útil sobre valores numéricos
df_livros.describe()
# Out:
#         titulo                                            sinopse  \
# count       10                                                 10
# unique      10                                                 10
# top     Carrie  Uma jovem com poderes telecinéticos se vinga d...
# freq         1                                                  1
#
#        data_lancamento                            link_afiliado
# count               10                                       10
# unique              10                                       10
# top         1974-04-05  https://www.amazon.com.br/dp/8556510412
# freq                 1                                        1

# %%
# Trás um gráfico da coluna livros, fazendo a contagem de valores e plotando em um gráfico de tipo barras
df_livros['titulo'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='titulo'>
